# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
 
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from xgboost import XGBClassifier
from sklearn import metrics
import xgboost as xgb

from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout
from keras.layers import Input, Dense
sns.set()
# Out:
# 2024-05-16 22:58:32.238528: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-05-16 22:58:32.239817: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-05-16 22:58:32.265704: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-05-16 22:58:32.266253: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-16 22:58:32.809769: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
file_path = 'BTC-USD.csv' 
df = pd.read_csv(file_path, parse_dates=['Date'])
df = df.sort_values('Date')
print(df)
# Out:
#            Date          Open          High           Low         Close  \
# 0    2014-09-17    465.864014    468.174011    452.421997    457.334015
# 1    2014-09-18    456.859985    456.859985    413.104004    424.440002
# 2    2014-09-19    424.102997    427.834991    384.532013    394.795990
# 3    2014-09-20    394.673004    423.295990    389.882996    408.903992
# 4    2014-09-21    408.084991    412.425995    393.181000    398.821014
# ...         ...           ...           ...           ...           ...
# 3525 2024-05-12  60793.503906  61818.156250  60632.601563  61448.394531
# 3526 2024-05-13  61451.218750  63422.660156  60769.839844  62901.449219
# 3527 2024-05-14  62900.773438  63092.125000  61123.765625  61552.789063
# 3528 2024-05-15  61553.988281  66454.453125  61330.410156  66267.492188
# 3529 2024-05-16  66253.937500  66591.296875  64678.179688  65109.988281
#
#          Adj Close       Volume
# 0       457.334015     21056800
# 1       424.440002     34483200
# 2       394.795990     37919700
# 3       408.903992     36863600
# 4       398.821014     26580100
# ...            ...          ...
# 3525  61448.394531  13800459405
# 3526  62901.449219  27889181179
# 3527  61552.789063  28186271527
# 3528  66267.492188  39815167074
# 3529  65109.988281  33482618880
#
# [3530 rows x 7 columns]

# %%
ax = df.plot(x='Date', y='Close')
ax.set_title('Bitcoin price')
ax.set_xlabel('Date')
ax.set_ylabel('Close Price (USD)')
plt.show()

# %%
shifted_rows = 100
df['Prediction'] = df[['Close']].shift(-shifted_rows)
print(df['Prediction'])
# Out:
# 0       327.924011
# 1       315.863007
# 2       317.239014
# 3       312.670013
# 4       310.737000
#            ...
# 3525           NaN
# 3526           NaN
# 3527           NaN
# 3528           NaN
# 3529           NaN
# Name: Prediction, Length: 3530, dtype: float64

# %%
# Training dataset 
training_data = np.array(df[['Close']][:-shifted_rows])
print(training_data)

y = (df['Prediction'].values)[:-shifted_rows]
print(y)
# Out:
# [[  457.334015]
#  [  424.440002]
#  [  394.79599 ]
#  ...
#  [42583.582031]
#  [42658.667969]
#  [43084.671875]]
# [  327.924011   315.863007   317.239014 ... 61552.789063 66267.492188
#  65109.988281]

# %%
x_train, x_test, y_train, y_test = train_test_split(training_data, y, test_size=20)

# %% [markdown]
# ## Linear Regression

# %%
linReg = LinearRegression()
linReg.fit(x_train, y_train)
linReg_confidence = linReg.score(x_test, y_test) 
print(linReg_confidence)
# Out:
# 0.5132969941769959

# %%
future_values = np.array(df[['Close']][-shifted_rows:])
linReg_prediction = linReg.predict(future_values)

# %%
plt.plot(future_values, 'red', label = 'Real Price') 
plt.plot(linReg_prediction, 'blue', label='Predicted Price')
plt.xlabel('Time frame')
plt.ylabel('Price')
plt.title('BTC price prediction (Linear Regression Model)')
plt.legend()
plt.show()

# %% [markdown]
# ## SVR Model

# %%
svr_rbf = SVR(kernel='rbf', C= 1e2, gamma = 0.01) 
svr_poly = SVR(kernel = 'poly', C= 1e3, degree=2) 
y_rbf = svr_rbf.fit(x_train, y_train) 
y_poly = svr_poly.fit(x_train, y_train)

# %%
future_values = np.array(df[['Close']][-shifted_rows:])
y_rbf_prediction = svr_rbf.predict(future_values) 
y_poly_prediction = svr_poly.predict(future_values)

# %%
plt.plot(future_values, 'red', label = 'Original') 
plt.plot(y_rbf_prediction, 'green', label='SVR_rbf')
plt.plot(y_poly_prediction, 'blue', label='SVR_poly')
plt.xlabel('Time frame')
plt.ylabel('Price')
plt.title('BTC price prediction (SVR Model)')
plt.legend()
plt.show()

# %% [markdown]
# ## Neural Network Model

# %%
# Model architecture (MLP)
NN_model = Sequential([
    Dense(128, kernel_initializer='normal', activation='relu', input_dim=x_train.shape[1] ),
    Dense(256, kernel_initializer='normal', activation='relu'),
    Dense(256, kernel_initializer='normal', activation='relu'),
    Dense(256, kernel_initializer='normal', activation='relu'),
    Dense(1, kernel_initializer='normal', activation='linear'),
])

# Compile the model
NN_model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mean_absolute_error'])

# Training and validation
history = NN_model.fit(x_train, y_train, epochs=50, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/50
# 86/86 [==============================] - 1s 2ms/step - loss: 181701632.0000 - mean_absolute_error: 7636.5859 - val_loss: 91706296.0000 - val_mean_absolute_error: 5544.0015
# Epoch 2/50
# 86/86 [==============================] - 0s 1ms/step - loss: 105356760.0000 - mean_absolute_error: 5909.8281 - val_loss: 91176808.0000 - val_mean_absolute_error: 5488.5200
# Epoch 3/50
# 86/86 [==============================] - 0s 1ms/step - loss: 103577088.0000 - mean_absolute_error: 5864.9878 - val_loss: 95804968.0000 - val_mean_absolute_error: 5694.0684
# Epoch 4/50
# 86/86 [==============================] - 0s 1ms/step - loss: 102631144.0000 - mean_absolute_error: 5826.7632 - val_loss: 109342488.0000 - val_mean_absolute_error: 6086.9009
# Epoch 5/50
# 86/86 [==============================] - 0s 1ms/step - loss: 101390784.0000 - mean_absolute_error: 5794.8618 - val_loss: 97703560.0000 - val_mean_absolute_error: 5638.2178
# Epoch 6/50
# 86/86 [==============================] - 0s 1ms/step - loss: 105212440.0000 - mean_absolute_error: 5886.5947 - val_loss: 91487640.0000 - val_mean_absolute_error: 5532.8237
# Epoch 7/50
# 86/86 [==============================] - 0s 2ms/step - loss: 105474016.0000 - mean_absolute_error: 5864.7422 - val_loss: 94783696.0000 - val_mean_absolute_error: 5554.7168
# Epoch 8/50
# 86/86 [==============================] - 0s 1ms/step - loss: 104931000.0000 - mean_absolute_error: 5883.0220 - val_loss: 94337336.0000 - val_mean_absolute_error: 5542.2173
# Epoch 9/50
# 86/86 [==============================] - 0s 1ms/step - loss: 101826272.0000 - mean_absolute_error: 5803.6309 - val_loss: 106763480.0000 - val_mean_absolute_error: 5878.6470
# Epoch 10/50
# 86/86 [==============================] - 0s 1ms/step - loss: 110058416.0000 - mean_absolute_error: 6016.6841 - val_loss: 92202408.0000 - val_mean_absolute_error: 5564.7749
# Epoch 11/50
# 86/86 [==============================] - 0s 1ms/step - loss: 102295512.0000 - mean_absolute_error: 5819.9712 - val_loss: 94406984.0000 - val_mean_absolute_error: 5542.8994
# Epoch 12/50
# 86/86 [==============================] - 0s 1ms/step - loss: 101084656.0000 - mean_absolute_error: 5818.1948 - val_loss: 91091152.0000 - val_mean_absolute_error: 5484.4658
# Epoch 13/50
# 86/86 [==============================] - 0s 1ms/step - loss: 104608632.0000 - mean_absolute_error: 5882.9995 - val_loss: 115501240.0000 - val_mean_absolute_error: 6101.5273
# Epoch 14/50
# 86/86 [==============================] - 0s 1ms/step - loss: 110432048.0000 - mean_absolute_error: 6008.5952 - val_loss: 117652496.0000 - val_mean_absolute_error: 6306.0640
# Epoch 15/50
# 86/86 [==============================] - 0s 1ms/step - loss: 112811104.0000 - mean_absolute_error: 6038.3232 - val_loss: 91076856.0000 - val_mean_absolute_error: 5511.9204
# Epoch 16/50
# 86/86 [==============================] - 0s 1ms/step - loss: 105693376.0000 - mean_absolute_error: 5899.8921 - val_loss: 99578792.0000 - val_mean_absolute_error: 5685.5303
# Epoch 17/50
# 86/86 [==============================] - 0s 1ms/step - loss: 103930248.0000 - mean_absolute_error: 5856.3433 - val_loss: 94465464.0000 - val_mean_absolute_error: 5648.0815
# Epoch 18/50
# 86/86 [==============================] - 0s 1ms/step - loss: 101947696.0000 - mean_absolute_error: 5801.6431 - val_loss: 91005320.0000 - val_mean_absolute_error: 5508.2012
# Epoch 19/50
# 86/86 [==============================] - 0s 1ms/step - loss: 102976144.0000 - mean_absolute_error: 5839.8203 - val_loss: 90807536.0000 - val_mean_absolute_error: 5491.8965
# Epoch 20/50
# 86/86 [==============================] - 0s 1ms/step - loss: 102747560.0000 - mean_absolute_error: 5793.9282 - val_loss: 90891880.0000 - val_mean_absolute_error: 5501.0669
# Epoch 21/50
# 86/86 [==============================] - 0s 1ms/step - loss: 104858440.0000 - mean_absolute_error: 5868.4600 - val_loss: 103517544.0000 - val_mean_absolute_error: 5925.7197
# Epoch 22/50
# 86/86 [==============================] - 0s 1ms/step - loss: 102805976.0000 - mean_absolute_error: 5837.2285 - val_loss: 94623256.0000 - val_mean_absolute_error: 5653.9492
# Epoch 23/50
# 86/86 [==============================] - 0s 1ms/step - loss: 104653952.0000 - mean_absolute_error: 5879.5176 - val_loss: 97810888.0000 - val_mean_absolute_error: 5756.2490
# Epoch 24/50
# 86/86 [==============================] - 0s 1ms/step - loss: 101090424.0000 - mean_absolute_error: 5779.4404 - val_loss: 91518624.0000 - val_mean_absolute_error: 5534.1450
# Epoch 25/50
# 86/86 [==============================] - 0s 1ms/step - loss: 104557800.0000 - mean_absolute_error: 5886.1636 - val_loss: 92390184.0000 - val_mean_absolute_error: 5571.4780
# Epoch 26/50
# 86/86 [==============================] - 0s 1ms/step - loss: 102307584.0000 - mean_absolute_error: 5779.2251 - val_loss: 93518408.0000 - val_mean_absolute_error: 5614.1787
# Epoch 27/50
# 86/86 [==============================] - 0s 1ms/step - loss: 102773952.0000 - mean_absolute_error: 5825.6123 - val_loss: 95754592.0000 - val_mean_absolute_error: 5575.0640
# Epoch 28/50
# 86/86 [==============================] - 0s 1ms/step - loss: 104513080.0000 - mean_absolute_error: 5836.9976 - val_loss: 98555728.0000 - val_mean_absolute_error: 5779.6094
# Epoch 29/50
# 86/86 [==============================] - 0s 1ms/step - loss: 101774152.0000 - mean_absolute_error: 5801.3438 - val_loss: 90758456.0000 - val_mean_absolute_error: 5485.7246
# Epoch 30/50
# 86/86 [==============================] - 0s 1ms/step - loss: 102907840.0000 - mean_absolute_error: 5827.4111 - val_loss: 93165872.0000 - val_mean_absolute_error: 5602.1528
# Epoch 31/50
# 86/86 [==============================] - 0s 1ms/step - loss: 101882376.0000 - mean_absolute_error: 5779.1636 - val_loss: 99907640.0000 - val_mean_absolute_error: 5821.2866
# Epoch 32/50
# 86/86 [==============================] - 0s 1ms/step - loss: 104904904.0000 - mean_absolute_error: 5833.2729 - val_loss: 109621336.0000 - val_mean_absolute_error: 6099.4917
# Epoch 33/50
# 86/86 [==============================] - 0s 1ms/step - loss: 111148408.0000 - mean_absolute_error: 6008.7817 - val_loss: 122214992.0000 - val_mean_absolute_error: 6429.7935
# Epoch 34/50
# 86/86 [==============================] - 0s 1ms/step - loss: 103587984.0000 - mean_absolute_error: 5831.5264 - val_loss: 92954720.0000 - val_mean_absolute_error: 5594.6846
# Epoch 35/50
# 86/86 [==============================] - 0s 1ms/step - loss: 103500584.0000 - mean_absolute_error: 5854.6406 - val_loss: 90794000.0000 - val_mean_absolute_error: 5496.1309
# Epoch 36/50
# 86/86 [==============================] - 0s 1ms/step - loss: 108061392.0000 - mean_absolute_error: 5940.5669 - val_loss: 94769768.0000 - val_mean_absolute_error: 5545.2734
# Epoch 37/50
# 86/86 [==============================] - 0s 1ms/step - loss: 104828000.0000 - mean_absolute_error: 5887.2461 - val_loss: 90987448.0000 - val_mean_absolute_error: 5508.2417
# Epoch 38/50
# 86/86 [==============================] - 0s 1ms/step - loss: 103525904.0000 - mean_absolute_error: 5844.1719 - val_loss: 90709232.0000 - val_mean_absolute_error: 5484.5786
# Epoch 39/50
# 86/86 [==============================] - 0s 1ms/step - loss: 102961944.0000 - mean_absolute_error: 5823.1465 - val_loss: 102563816.0000 - val_mean_absolute_error: 5901.3730
# Epoch 40/50
# 86/86 [==============================] - 0s 1ms/step - loss: 107403296.0000 - mean_absolute_error: 5944.6743 - val_loss: 94125272.0000 - val_mean_absolute_error: 5527.1372
# Epoch 41/50
# 86/86 [==============================] - 0s 1ms/step - loss: 101903328.0000 - mean_absolute_error: 5826.4712 - val_loss: 98861568.0000 - val_mean_absolute_error: 5790.5977
# Epoch 42/50
# 86/86 [==============================] - 0s 1ms/step - loss: 102568432.0000 - mean_absolute_error: 5827.8745 - val_loss: 91348928.0000 - val_mean_absolute_error: 5527.2778
# Epoch 43/50
# 86/86 [==============================] - 0s 1ms/step - loss: 102852400.0000 - mean_absolute_error: 5818.5244 - val_loss: 92540696.0000 - val_mean_absolute_error: 5579.3521
# Epoch 44/50
# 86/86 [==============================] - 0s 1ms/step - loss: 101688736.0000 - mean_absolute_error: 5784.1621 - val_loss: 98445472.0000 - val_mean_absolute_error: 5778.3037
# Epoch 45/50
# 86/86 [==============================] - 0s 1ms/step - loss: 103800360.0000 - mean_absolute_error: 5828.9849 - val_loss: 116852408.0000 - val_mean_absolute_error: 6293.9707
# Epoch 46/50
# 86/86 [==============================] - 0s 1ms/step - loss: 102311824.0000 - mean_absolute_error: 5792.3008 - val_loss: 109486536.0000 - val_mean_absolute_error: 6099.3379
# Epoch 47/50
# 86/86 [==============================] - 0s 1ms/step - loss: 102602888.0000 - mean_absolute_error: 5829.2710 - val_loss: 92059536.0000 - val_mean_absolute_error: 5476.6362
# Epoch 48/50
# 86/86 [==============================] - 0s 1ms/step - loss: 102533280.0000 - mean_absolute_error: 5808.9531 - val_loss: 91846568.0000 - val_mean_absolute_error: 5551.4424
# Epoch 49/50
# 86/86 [==============================] - 0s 1ms/step - loss: 103696088.0000 - mean_absolute_error: 5804.0903 - val_loss: 91225000.0000 - val_mean_absolute_error: 5521.9121
# Epoch 50/50
# 86/86 [==============================] - 0s 1ms/step - loss: 100710376.0000 - mean_absolute_error: 5760.4507 - val_loss: 98805992.0000 - val_mean_absolute_error: 5790.6377

# %%
future_values = np.array(df[['Close']][-shifted_rows:])
NN_pred = NN_model.predict(future_values)
# Out:
# 4/4 [==============================] - 0s 1ms/step

# %%
plt.plot(future_values, 'red', label = 'Original') 
plt.plot(NN_pred, 'blue', label='NN_pred')
plt.xlabel('Time frame')
plt.ylabel('Price')
plt.title('BTC price prediction (NN Model)')
plt.legend()
plt.show()

# %% [markdown]
# ## XGBoost Model

# %%
# Define XGBoost regressor
xg_reg = xgb.XGBRegressor(objective ='reg:absoluteerror', colsample_bytree = 0.3, learning_rate = 0.01,
                max_depth = 50, alpha = 1, n_estimators = 1000)

# Train the model
xg_reg.fit(x_train,y_train)

# Predict on test data
future_values = np.array(df[['Close']][-shifted_rows:])
xgb_pred = xg_reg.predict(future_values)

# %%
plt.plot(future_values, 'red', label = 'Original') 
plt.plot(xgb_pred, 'blue', label='xgb_pred')
plt.xlabel('Time frame')
plt.ylabel('Price')
plt.title('BTC price prediction (XGBoost Model)')
plt.legend()
plt.show()
